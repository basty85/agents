# %%
my_dict = {"wurstkosten": 2.5, "lyonerkosten": 3.5}

values: list[float] = []
keys: list[str] = []

for key, value in my_dict.items():
    values.append(float(value))
    keys.append(str(key))

print(keys)
print(values)
# Out:
# ['wurst', 'kosten']
# [2.5, 3.5]
